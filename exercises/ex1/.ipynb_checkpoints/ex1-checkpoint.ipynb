# %% [markdown]
# # Exercise 1
# In this notebook I will perform the exercises from the course using Python 3.

# %% [markdown]
# ## Linear regression with one variable
#
# Suppose you are the CEO of a
# restaurant franchise and are considering different cities for opening a new
# outlet.
# The chain already has trucks in various cities and you have data for
# profits and populations from the cities.
# You would like to use this data to help you select which city to expand
# to next.
#
# The file `ex1data1.txt` contains the dataset for our linear regression problem. The first column is the population of a city and the second column is
# the profit of a food truck in that city. A negative value for profit indicates a
# loss.

# %%
# libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
from mpl_toolkits import mplot3d

# %% [markdown]
# ### Plotting the Data
# Before starting on any task, it is often useful to understand the data by
# visualizing it. For this dataset, you can use a scatter plot to visualize the
# data, since it has only two properties to plot (profit and population).

# %%
# import data
dat = pd.read_csv('ex1/ex1data1.txt',header=None)
dat.columns = ['population','profit']
dat.head()
# Out:
#    population   profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
# plot data as scatterplot
plt.scatter(dat['population'],dat['profit'],marker='x')
plt.xlabel('population')
plt.ylabel('profit')
plt.title('D')
# Out:
# Text(0.5, 1.0, 'D')

# %% [markdown]
# ### Gradient Descent
# Fit linear regression parameters $\theta$ to our dataset.
#
# We add another dimension to our data to accommodate the
# θ0 intercept term. We also initialize the initial parameters to 0 and the
# learning rate alpha to 0.01.

# %%
# add a column of 1s to X (intercept)
X = np.c_[np.ones(len(dat)),np.array(dat['population'])]
Y = np.array(dat['profit'])

# init fitting parameters
theta = np.zeros(2)

# convergence parameters
iterations = 1500
alpha = 0.01 # learning rate

# %% [markdown]
# - **Define function to compute the cost**: linear model and mean squared error

# %%
# function to calculate y of a linear model
def linear_model(x_values,pars):
    # linear model
    r = pars.dot(np.transpose(x_values))
    return r
    
# function to compute the cost
def compute_cost(x_values,pars,y_values):
    # calculate hypothesis model values (y') from x_values and init_par
    y_hypothesis = linear_model(x_values,pars)
    
    # compute unbiased mean squared error
    J = 1/(2*len(y_values))*sum((y_hypothesis-y_values)**2)
    return J

# %%
# confirm cost of 32.07
compute_cost(X,theta,Y)
# Out:
# 32.072733877455654

# %% [markdown]
# - **Define function to update parameters simultaneously**:

# %%
# function to compute step gradient
def compute_gradient(x_values,pars,y_values,l_rate):
    # compute difference from linear model to y_values
    obs_er = (linear_model(x_values,pars)-y_values)
    
    # compute new theta values
    theta_new = pars - l_rate*(1/len(y_values))*obs_er.dot((x_values))
    return theta_new
    
# function for simultaneous parameter update
def gradient_descent(x_values,pars,y_values,l_rate,n_iterations):
    cost = []
    
    # compute and save cost
    cost.append(compute_cost(x_values,pars,y_values))
        
    pars_list = [pars]
    for i in range(n_iterations):
        # update parameters
        pars = compute_gradient(x_values,pars,y_values,l_rate)
        pars_list.append(pars)
        
        # compute and save cost
        cost.append(compute_cost(x_values,pars,y_values))
        
    return [cost,pars_list]

# %%
# perform gradient descent
gd_result = gradient_descent(X,theta,Y,alpha,iterations)

# visualize performance
plt.plot(gd_result[0])
plt.title('Gradient Descent Performance')
plt.ylabel(r'$J(\theta)$')
plt.xlabel(r'$Iteration$')
# Out:
# Text(0.5, 0, '$Iteration$')

# %%
# plot data as scatterplot with linear model
plt.scatter(dat['population'],dat['profit'],marker='x')
plt.plot(dat['population'],linear_model(X,gd_result[1][-1]),c='r')
plt.xlabel('population')
plt.ylabel('profit')
plt.title('Data and predicted line')
plt.show()

# print
print(gd_result[1][-1])
# Out:
# [-3.63029144  1.16636235]

# %% [markdown]
# - **Visualize surface and contour plots of regression**

# %%
df = pd.DataFrame.from_dict({
    'cost_vals': gd_result[0],
    'theta_0': np.array(gd_result[1])[:,0],
    'theta_1': np.array(gd_result[1])[:,1]
})
df.head()
# Out:
#    cost_vals   theta_0   theta_1
# 0  32.072734  0.000000  0.000000
# 1   6.737190  0.058391  0.653288
# 2   5.931594  0.062892  0.770010
# 3   5.901155  0.057823  0.791348
# 4   5.895229  0.051064  0.795730

# %%
# Contour plot
x = np.linspace(-5,5,100)
y = np.linspace(0,1.5,100)
theta_0, theta_1 = np.meshgrid(x, y)

# %%
# compute costs for all meshgrid
Z = np.zeros(theta_0.shape)
for i in range(Z.shape[0]):
    for j in range(Z.shape[1]):
        tmp_pars = np.array([theta_0[i,j],theta_1[i,j]])
        Z[i,j] = compute_cost(np.c_[np.ones(len(dat)),np.array(dat['population'])],tmp_pars,dat['profit'])

# %%
# Make the 3D plot
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_trisurf(theta_1.flatten(),theta_0.flatten(),Z.flatten(),cmap=plt.cm.viridis, linewidth=0.2)
ax.set_xlabel('theta_1')
ax.set_ylabel('theta_0')
ax.set_zlabel('cost_vals');
plt.show()

# %%
# contour
plt.contour(theta_0,theta_1,Z)
plt.scatter(gd_result[1][-1][0],gd_result[1][-1][1],c='r',marker='x')
# parameters trajectory
plt.scatter(df['theta_0'],df['theta_1'],c='r',marker='x',alpha=0.07)
plt.xlabel('theta_0')
plt.ylabel('theta_1')
plt.title('Contour plot')
plt.show()

# %% [markdown]
# ## Linear regression with multiple variables

# %% [markdown]
# You will implement linear regression with multiple variables to
# predict the prices of houses. Suppose you are selling your house and you
# want to know what a good market price would be. One way to do this is to
# first collect information on recent houses sold and make a model of housing
# prices.
#
#
# The file `ex1data2.txt` contains a training set of housing prices in Portland, Oregon. The first column is the size of the house (in square feet), the
# second column is the number of bedrooms, and the third column is the price
# of the house.

# %%
# import data
dat_mult = pd.read_csv('ex1/ex1data2.txt',header=None)
dat_mult.columns = ['size','n_bedr','price']
dat_mult.head()
# Out:
#    size  n_bedr   price
# 0  2104       3  399900
# 1  1600       3  329900
# 2  2400       3  369000
# 3  1416       2  232000
# 4  3000       4  539900

# %% [markdown]
# ### Feature Normalization
# By looking at the values, note that house sizes are about
# 1000 times the number of bedrooms. When features differ by orders of magnitude, first performing feature scaling can make gradient descent converge
# much more quickly.
# Tasks:
# - Subtract the mean value of each feature from the dataset.
# - After subtracting the mean, additionally scale (divide) the feature values by their respective "standard deviations.”

# %%
dat_mult.describe()
# Out:
#               size     n_bedr          price
# count    47.000000  47.000000      47.000000
# mean   2000.680851   3.170213  340412.659574
# std     794.702354   0.760982  125039.899586
# min     852.000000   1.000000  169900.000000
# 25%    1432.000000   3.000000  249900.000000
# 50%    1888.000000   3.000000  299900.000000
# 75%    2269.000000   4.000000  384450.000000
# max    4478.000000   5.000000  699900.000000

# %%
# normalize each feature (independently of feature type)
dm_sc=(dat_mult-dat_mult.mean())/dat_mult.std()
dm_sc.describe()
# Out:
#                size        n_bedr         price
# count  4.700000e+01  4.700000e+01  4.700000e+01
# mean   3.779483e-17  2.746030e-16 -9.684924e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.445423e+00 -2.851859e+00 -1.363666e+00
# 25%   -7.155897e-01 -2.236752e-01 -7.238702e-01
# 50%   -1.417900e-01 -2.236752e-01 -3.239979e-01
# 75%    3.376348e-01  1.090417e+00  3.521863e-01
# max    3.117292e+00  2.404508e+00  2.874981e+00

# %% [markdown]
# ### Gradient Descent
# In the multivariate case, the cost function can
# also be written in the following vectorized form:
#
# $$J(\theta)=\frac{1}{2m}(X\theta-\vec{y}^{\,})^T(X\theta-\vec{y}^{\,})$$

# %%
# add a column of 1s to X (intercept)
X = np.c_[np.ones(len(dm_sc)),np.array(dm_sc[['size','n_bedr']])]
Y = np.array(dm_sc['price'])

# init fitting parameters
theta = np.zeros(3)

# convergence parameters
iterations = 1500
alpha = 0.01 # learning rate

# %%
# perform gradient descent
gd_result = gradient_descent(X,theta,Y,alpha,iterations)

# visualize performance
plt.plot(gd_result[0])
plt.title('Gradient Descent Performance')
plt.ylabel(r'$J(\theta)$')
plt.xlabel(r'$Iteration$')

# optimal parameters
pars_gd = gd_result[1][-1]
print(pars_gd)
# Out:
# [-1.10939626e-16  8.84042349e-01 -5.24551809e-02]

# %%
# predicted plane
# size and number of bedrooms
xx, yy = np.meshgrid(np.linspace(-5,5,50),np.linspace(-5,5,50))

# compute prices for all meshgrid given the linear model with optimized parameters
zz = 1*pars_opt[0] + xx*pars_opt[1] + yy*pars_opt[2]

# %%
# Make the 3D plot
fig = plt.figure()
ax = fig.gca(projection='3d')

# data points
ax.scatter(dm_sc.iloc[:,0],dm_sc.iloc[:,1],dm_sc.iloc[:,2],cmap=plt.cm.viridis, linewidth=0.2)

ax.plot_surface(xx,yy,zz,color='r')

ax.set_xlabel('size')
ax.set_ylabel('n_bedrooms')
ax.set_zlabel('price')
ax.set_title('Multidimensional regression')

ax.view_init()
plt.show()

# %% [markdown]
# ### Selecting learning rates
# The next phase in ex1 multi.m will call your gradientDescent.m function and run gradient descent for about 50 iterations at the chosen learning
# rate. The function should also return the history of J(θ) values in a vector
# J. After the last iteration, the ex1 multi.m script plots the J values against
# the number of the iterations.
#
#
#  We recommend trying values of the learning rate $\alpha$ on a log-scale, at multiplicative
# steps of about 3 times the previous value (i.e., 0.3, 0.1, 0.03, 0.01 and so on).
# You may also want to adjust the number of iterations you are running if that
# will help you see the overall trend in the curve.

# %%
# perform gradient descent
l_rates = [1,0.5,0.3,0.1,0.05,0.03,0.01,0.005,0.003,0.001]
its = 50
cost_trajs = []
for a in l_rates:
    # compute gradient descent
    tmp_gd = gradient_descent(X,theta,Y,a,its)
    
    # save cost function trajectories
    cost_trajs.append(tmp_gd[0])

# %%
plt.plot(np.array(cost_trajs).T)
plt.gca().legend(l_rates)
plt.xlabel('Iteration')
plt.ylabel(r'$J(\theta)$')
plt.title('Selecting learning rates')
plt.show()

# %% [markdown]
# ### Normal Equations
# In the lecture videos, you learned that the closed-form solution to linear
# regression is
#
# $$\theta=(X^TX)^{-1}X^{T}\vec{y}^{\,}$$
#
#
# Using this formula does not require any feature scaling, and you will get
# an exact solution in one calculation: there is no “loop until convergence” like
# in gradient descent. Remember that while you don’t need to scale your features, we still
# need to add a column of 1’s to the X matrix to have an intercept term ($\theta_0$)

# %%
# compute formula
pars_ne = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(Y)
print(pars_ne)

# compare
print(pars_gd)
# Out:
# [-1.11022302e-16  8.84765988e-01 -5.31788197e-02]
# [-1.10939626e-16  8.84042349e-01 -5.24551809e-02]

# %% [markdown]
# Indeed, they are in the same range.

# %% [markdown]
# #### Extra
# Now, once you have found θ using this
# method, use it to make a price prediction for a 1650-square-foot house with
# 3 bedrooms. You should find that gives the same predicted price as the value
# you obtained using the model fit with gradient descent

# %%
# test point
# normalize test point to make prediction in fitted model
test_p = list((np.array([1650,3])-dat_mult[['size','n_bedr']].mean())/dat_mult[['size','n_bedr']].std())
# add 1 for intercept coefficient
test_p = np.array([1]+test_p)
test_p
# Out:
# array([ 1.        , -0.4412732 , -0.22367519])

# %%
# predict normalized price in both cases:
# gradient descent
y_gd = pars_gd.T.dot(test_p)*dat_mult['price'].std()+dat_mult['price'].mean()
print(y_gd)
# normal equation
y_ne = pars_ne.T.dot(test_p)*dat_mult['price'].std()+dat_mult['price'].mean()
print(y_ne)
# Out:
# 293101.1534175584
# 293081.4643348962

# %%
# Make the 3D plot
fig = plt.figure()
ax = fig.gca(projection='3d')

# data points
ax.scatter(dat_mult.iloc[:,0],dat_mult.iloc[:,1],dat_mult.iloc[:,2])

ax.scatter(1650,3,y_gd,color='r',alpha=0.4)
ax.scatter(1650,3,y_ne,color='yellow')

ax.set_xlabel('size')
ax.set_ylabel('n_bedrooms')
ax.set_zlabel('price')
ax.set_title('Multidimensional regression prediction')

ax.view_init(10)
plt.show()
